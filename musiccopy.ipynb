# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import os
import math
import librosa

DATASET_PATH = "/content/drive/MyDrive/Data/genres_original"
JSON_PATH = "data_15.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
        
        
if __name__ == "__main__":
    save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/Data/genres_original/metal/metal.00000.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00000.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00000.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00000.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00008.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00008.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00008.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00008.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00008.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00008.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00008.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00008.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00008.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00008.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00002.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00002.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00002.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00002.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00002.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00002.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00002.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00002.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00002.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00002.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00007.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00007.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00007.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00007.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00007.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00007.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00007.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00007.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00007.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00007.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00003.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00003.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00003.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00003.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00003.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00003.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00003.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00003.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00003.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00003.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00006.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00006.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00006.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00006.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00006.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00006.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00006.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00006.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00006.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00006.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00005.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00005.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00005.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00005.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00005.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00005.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00005.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00005.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00005.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00005.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00001.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00001.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00001.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00001.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00001.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00001.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00001.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00001.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00001.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00001.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00004.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00004.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00004.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00004.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00004.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00004.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00004.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00004.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00004.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00004.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00009.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00009.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00009.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00009.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00009.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00009.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00009.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00009.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00009.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00009.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00022.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00022.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00022.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00022.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00022.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00022.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00022.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00022.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00022.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00022.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00013.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00013.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00013.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00013.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00013.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00013.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00013.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00013.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00013.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00013.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00010.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00010.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00010.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00010.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00010.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00010.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00010.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00010.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00010.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00010.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00015.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00015.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00015.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00015.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00015.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00015.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00015.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00015.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00015.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00015.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00011.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00011.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00011.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00011.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00011.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00011.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00011.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00011.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00011.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00011.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00016.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00016.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00016.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00016.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00016.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00016.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00016.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00016.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00016.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00016.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00017.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00017.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00017.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00017.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00017.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00017.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00017.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00017.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00017.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00017.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00023.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00023.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00023.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00023.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00023.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00023.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00023.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00023.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00023.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00023.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00020.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00020.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00020.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00020.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00020.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00020.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00020.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00020.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00020.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00020.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00012.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00012.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00012.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00012.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00012.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00012.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00012.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00012.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00012.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00012.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00021.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00021.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00021.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00021.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00021.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00021.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00021.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00021.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00021.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00021.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00014.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00014.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00014.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00014.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00014.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00014.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00014.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00014.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00014.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00014.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00019.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00019.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00019.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00019.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00019.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00019.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00019.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00019.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00019.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00019.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00018.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00018.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00018.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00018.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00018.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00018.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00018.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00018.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00018.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00018.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00031.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00031.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00031.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00031.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00031.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00031.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00031.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00031.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00031.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00031.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00035.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00035.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00035.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00035.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00035.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00035.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00035.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00035.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00035.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00035.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00025.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00025.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00025.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00025.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00025.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00025.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00025.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00025.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00025.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00025.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00037.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00037.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00037.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00037.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00037.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00037.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00037.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00037.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00037.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00037.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00028.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00028.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00028.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00028.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00028.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00028.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00028.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00028.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00028.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00028.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00024.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00024.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00024.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00024.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00024.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00024.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00024.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00024.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00024.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00024.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00029.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00029.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00029.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00029.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00029.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00029.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00029.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00029.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00029.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00029.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00027.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00027.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00027.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00027.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00027.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00027.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00027.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00027.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00027.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00027.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00026.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00026.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00026.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00026.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00026.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00026.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00026.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00026.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00026.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00026.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00034.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00034.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00034.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00034.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00034.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00034.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00034.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00034.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00034.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00034.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00032.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00032.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00032.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00032.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00032.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00032.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00032.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00032.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00032.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00032.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00030.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00030.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00030.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00030.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00030.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00030.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00030.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00030.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00030.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00030.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00033.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00033.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00033.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00033.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00033.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00033.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00033.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00033.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00033.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00033.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00036.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00036.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00036.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00036.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00036.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00036.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00036.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00036.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00036.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00036.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00040.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00040.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00040.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00040.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00040.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00040.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00040.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00040.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00040.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00040.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00049.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00049.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00049.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00049.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00049.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00049.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00049.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00049.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00049.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00049.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00039.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00039.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00039.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00039.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00039.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00039.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00039.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00039.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00039.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00039.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00045.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00045.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00045.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00045.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00045.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00045.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00045.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00045.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00045.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00045.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00047.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00047.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00047.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00047.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00047.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00047.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00047.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00047.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00047.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00047.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00044.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00044.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00044.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00044.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00044.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00044.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00044.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00044.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00044.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00044.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00048.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00048.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00048.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00048.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00048.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00048.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00048.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00048.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00048.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00048.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00038.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00038.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00038.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00038.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00038.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00038.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00038.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00038.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00038.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00038.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00051.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00051.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00051.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00051.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00051.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00051.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00051.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00051.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00051.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00051.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00041.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00041.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00041.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00041.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00041.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00041.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00041.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00041.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00041.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00041.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00046.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00046.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00046.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00046.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00046.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00046.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00046.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00046.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00046.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00046.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00042.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00042.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00042.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00042.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00042.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00042.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00042.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00042.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00042.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00042.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00050.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00050.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00050.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00050.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00050.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00050.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00050.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00050.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00050.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00050.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00043.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00043.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00043.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00043.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00043.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00043.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00043.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00043.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00043.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00043.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00054.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00054.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00054.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00054.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00054.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00054.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00054.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00054.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00054.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00054.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00058.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00058.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00058.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00058.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00058.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00058.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00058.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00058.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00058.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00058.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00059.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00059.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00059.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00059.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00059.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00059.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00059.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00059.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00059.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00059.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00052.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00052.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00052.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00052.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00052.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00052.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00052.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00052.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00052.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00052.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00063.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00063.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00063.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00063.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00063.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00063.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00063.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00063.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00063.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00063.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00056.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00056.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00056.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00056.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00056.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00056.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00056.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00056.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00056.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00056.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00061.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00061.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00061.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00061.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00061.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00061.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00061.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00061.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00061.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00061.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00055.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00055.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00055.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00055.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00055.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00055.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00055.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00055.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00055.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00055.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00062.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00062.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00062.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00062.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00062.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00062.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00062.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00062.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00062.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00062.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00064.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00064.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00064.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00064.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00064.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00064.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00064.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/metal/metal.00064.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/metal/metal.00064.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/metal/metal.00064.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/metal/metal.00057.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/metal/metal.00057.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/metal/metal.00057.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/metal/metal.00057.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/metal/metal.00057.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/metal/metal.00057.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/metal/metal.00057.wav, segment:7
# ...
# /content/drive/MyDrive/Data/genres_original/blues/blues.00088.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00088.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00088.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00088.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00088.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00088.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00090.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00090.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00090.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00090.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00090.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00090.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00090.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00090.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00090.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00090.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00086.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00086.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00086.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00086.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00086.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00086.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00086.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00086.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00086.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00086.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00089.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00089.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00089.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00089.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00089.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00089.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00089.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00089.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00089.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00089.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00084.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00084.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00084.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00084.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00084.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00084.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00084.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00084.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00084.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00084.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00085.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00085.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00085.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00085.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00085.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00085.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00085.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00085.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00085.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00085.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00091.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00091.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00091.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00091.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00091.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00091.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00091.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00091.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00091.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00091.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00082.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00082.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00082.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00082.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00082.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00082.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00082.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00082.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00082.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00082.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00081.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00081.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00081.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00081.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00081.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00081.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00081.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00081.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00081.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00081.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00080.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00080.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00080.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00080.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00080.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00080.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00080.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00080.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00080.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00080.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00087.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00087.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00087.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00087.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00087.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00087.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00087.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00087.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00087.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00087.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00083.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00083.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00083.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00083.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00083.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00083.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00083.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00083.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00083.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00083.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00079.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00079.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00079.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00079.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00079.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00079.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00079.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00079.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00079.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00079.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00098.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00098.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00098.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00098.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00098.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00098.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00098.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00098.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00098.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00098.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00097.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00097.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00097.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00097.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00097.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00097.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00097.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00097.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00097.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00097.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00099.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00099.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00099.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00099.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00099.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00099.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00099.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00099.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00099.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00099.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00095.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00095.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00095.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00095.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00095.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00095.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00095.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00095.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00095.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00095.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00094.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00094.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00094.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00094.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00094.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00094.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00094.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00094.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00094.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00094.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00093.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00093.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00093.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00093.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00093.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00093.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00093.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00093.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00093.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00093.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/blues.00096.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/blues.00096.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/blues.00096.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/blues.00096.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/blues.00096.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/blues.00096.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/blues.00096.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/blues.00096.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/blues.00096.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/blues.00096.wav, segment:10
# /content/drive/MyDrive/Data/genres_original/blues/Copy of blues.00001.wav, segment:1
# /content/drive/MyDrive/Data/genres_original/blues/Copy of blues.00001.wav, segment:2
# /content/drive/MyDrive/Data/genres_original/blues/Copy of blues.00001.wav, segment:3
# /content/drive/MyDrive/Data/genres_original/blues/Copy of blues.00001.wav, segment:4
# /content/drive/MyDrive/Data/genres_original/blues/Copy of blues.00001.wav, segment:5
# /content/drive/MyDrive/Data/genres_original/blues/Copy of blues.00001.wav, segment:6
# /content/drive/MyDrive/Data/genres_original/blues/Copy of blues.00001.wav, segment:7
# /content/drive/MyDrive/Data/genres_original/blues/Copy of blues.00001.wav, segment:8
# /content/drive/MyDrive/Data/genres_original/blues/Copy of blues.00001.wav, segment:9
# /content/drive/MyDrive/Data/genres_original/blues/Copy of blues.00001.wav, segment:10

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# path to json file that stores MFCCs and genre labels for each processed segment
DATA_PATH ="/content/data_15.json"

def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


if __name__ == "__main__":

    # load data
    X, y = load_data(DATA_PATH)

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

    # build network topology
    model = keras.Sequential([

        # input layer
        keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),

        # 1st dense layer
        keras.layers.Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        # 2nd dense layer
        keras.layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        # 3rd dense layer
        keras.layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        # output layer
        keras.layers.Dense(10, activation='softmax')
    ])

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=50)

    # plot accuracy and error as a function of the epochs
    plot_history(history)
# Out:
# Data succesfully loaded!
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 1690)              0
#
#  dense (Dense)               (None, 512)               865792
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 219/219 [==============================] - 7s 27ms/step - loss: 20.1406 - accuracy: 0.1375 - val_loss: 3.5050 - val_accuracy: 0.1014
# Epoch 2/50
# 219/219 [==============================] - 9s 41ms/step - loss: 5.8244 - accuracy: 0.1185 - val_loss: 3.4964 - val_accuracy: 0.0907
# Epoch 3/50
# 219/219 [==============================] - 6s 29ms/step - loss: 4.3011 - accuracy: 0.1155 - val_loss: 3.4933 - val_accuracy: 0.1157
# Epoch 4/50
# 219/219 [==============================] - 6s 29ms/step - loss: 3.8836 - accuracy: 0.1146 - val_loss: 3.4681 - val_accuracy: 0.1134
# Epoch 5/50
# 219/219 [==============================] - 7s 32ms/step - loss: 3.6732 - accuracy: 0.1291 - val_loss: 3.4436 - val_accuracy: 0.1444
# Epoch 6/50
# 219/219 [==============================] - 8s 38ms/step - loss: 3.6142 - accuracy: 0.1379 - val_loss: 3.4350 - val_accuracy: 0.1464
# Epoch 7/50
# 219/219 [==============================] - 8s 37ms/step - loss: 3.5402 - accuracy: 0.1495 - val_loss: 3.3996 - val_accuracy: 0.1657
# Epoch 8/50
# 219/219 [==============================] - 8s 38ms/step - loss: 3.5110 - accuracy: 0.1496 - val_loss: 3.3755 - val_accuracy: 0.1754
# Epoch 9/50
# 219/219 [==============================] - 9s 39ms/step - loss: 3.4613 - accuracy: 0.1611 - val_loss: 3.3814 - val_accuracy: 0.1664
# Epoch 10/50
# 219/219 [==============================] - 8s 35ms/step - loss: 3.4655 - accuracy: 0.1614 - val_loss: 3.3076 - val_accuracy: 0.1924
# Epoch 11/50
# 219/219 [==============================] - 8s 37ms/step - loss: 3.4156 - accuracy: 0.1771 - val_loss: 3.2703 - val_accuracy: 0.2044
# Epoch 12/50
# 219/219 [==============================] - 8s 37ms/step - loss: 3.3782 - accuracy: 0.1739 - val_loss: 3.2515 - val_accuracy: 0.2061
# Epoch 13/50
# 219/219 [==============================] - 10s 46ms/step - loss: 3.3483 - accuracy: 0.1799 - val_loss: 3.2181 - val_accuracy: 0.2197
# Epoch 14/50
# 219/219 [==============================] - 9s 41ms/step - loss: 3.3320 - accuracy: 0.1877 - val_loss: 3.2472 - val_accuracy: 0.1994
# Epoch 15/50
# 219/219 [==============================] - 8s 34ms/step - loss: 3.3143 - accuracy: 0.1851 - val_loss: 3.2248 - val_accuracy: 0.2004
# Epoch 16/50
# 219/219 [==============================] - 7s 33ms/step - loss: 3.2730 - accuracy: 0.1927 - val_loss: 3.1853 - val_accuracy: 0.2101
# Epoch 17/50
# 219/219 [==============================] - 7s 32ms/step - loss: 3.2569 - accuracy: 0.2122 - val_loss: 3.1506 - val_accuracy: 0.2254
# Epoch 18/50
# 219/219 [==============================] - 7s 30ms/step - loss: 3.2239 - accuracy: 0.2131 - val_loss: 3.1608 - val_accuracy: 0.2124
# Epoch 19/50
# 219/219 [==============================] - 7s 31ms/step - loss: 3.2098 - accuracy: 0.2195 - val_loss: 3.1027 - val_accuracy: 0.2334
# Epoch 20/50
# 219/219 [==============================] - 6s 28ms/step - loss: 3.1732 - accuracy: 0.2268 - val_loss: 3.0659 - val_accuracy: 0.2501
# Epoch 21/50
# 219/219 [==============================] - 9s 42ms/step - loss: 3.1368 - accuracy: 0.2270 - val_loss: 3.0438 - val_accuracy: 0.2514
# Epoch 22/50
# 219/219 [==============================] - 7s 34ms/step - loss: 3.1174 - accuracy: 0.2331 - val_loss: 3.0240 - val_accuracy: 0.2538
# Epoch 23/50
# 219/219 [==============================] - 6s 29ms/step - loss: 3.1127 - accuracy: 0.2307 - val_loss: 3.0075 - val_accuracy: 0.2574
# Epoch 24/50
# 219/219 [==============================] - 6s 29ms/step - loss: 3.0736 - accuracy: 0.2398 - val_loss: 2.9552 - val_accuracy: 0.2734
# Epoch 25/50
# 219/219 [==============================] - 6s 29ms/step - loss: 3.0430 - accuracy: 0.2444 - val_loss: 2.9436 - val_accuracy: 0.2751
# Epoch 26/50
# 219/219 [==============================] - 7s 31ms/step - loss: 3.0245 - accuracy: 0.2431 - val_loss: 2.9340 - val_accuracy: 0.2658
# Epoch 27/50
# 219/219 [==============================] - 7s 32ms/step - loss: 2.9750 - accuracy: 0.2437 - val_loss: 2.8831 - val_accuracy: 0.2791
# Epoch 28/50
# 219/219 [==============================] - 10s 44ms/step - loss: 2.9721 - accuracy: 0.2498 - val_loss: 2.9157 - val_accuracy: 0.2601
# Epoch 29/50
# 219/219 [==============================] - 8s 36ms/step - loss: 2.9213 - accuracy: 0.2607 - val_loss: 2.8524 - val_accuracy: 0.2774
# Epoch 30/50
# 219/219 [==============================] - 8s 35ms/step - loss: 2.8910 - accuracy: 0.2648 - val_loss: 2.8044 - val_accuracy: 0.3014
# Epoch 31/50
# 219/219 [==============================] - 8s 36ms/step - loss: 2.8593 - accuracy: 0.2697 - val_loss: 2.7876 - val_accuracy: 0.2941
# Epoch 32/50
# 219/219 [==============================] - 7s 32ms/step - loss: 2.8351 - accuracy: 0.2653 - val_loss: 2.7393 - val_accuracy: 0.3101
# Epoch 33/50
# 219/219 [==============================] - 7s 33ms/step - loss: 2.7959 - accuracy: 0.2768 - val_loss: 2.7191 - val_accuracy: 0.3061
# Epoch 34/50
# 219/219 [==============================] - 8s 38ms/step - loss: 2.7619 - accuracy: 0.2794 - val_loss: 2.7431 - val_accuracy: 0.2924
# Epoch 35/50
# 219/219 [==============================] - 6s 28ms/step - loss: 2.7452 - accuracy: 0.2843 - val_loss: 2.6697 - val_accuracy: 0.3184
# Epoch 36/50
# 219/219 [==============================] - 6s 28ms/step - loss: 2.7031 - accuracy: 0.2846 - val_loss: 2.6593 - val_accuracy: 0.3208
# Epoch 37/50
# 219/219 [==============================] - 4s 19ms/step - loss: 2.6778 - accuracy: 0.2946 - val_loss: 2.6085 - val_accuracy: 0.3284
# Epoch 38/50
# 219/219 [==============================] - 3s 14ms/step - loss: 2.6528 - accuracy: 0.2971 - val_loss: 2.6105 - val_accuracy: 0.3214
# Epoch 39/50
# 219/219 [==============================] - 3s 14ms/step - loss: 2.6329 - accuracy: 0.2928 - val_loss: 2.5560 - val_accuracy: 0.3391
# Epoch 40/50
# 219/219 [==============================] - 3s 15ms/step - loss: 2.6031 - accuracy: 0.3004 - val_loss: 2.5803 - val_accuracy: 0.3308
# Epoch 41/50
# 219/219 [==============================] - 5s 24ms/step - loss: 2.5559 - accuracy: 0.3090 - val_loss: 2.5305 - val_accuracy: 0.3421
# Epoch 42/50
# 219/219 [==============================] - 8s 35ms/step - loss: 2.5333 - accuracy: 0.3200 - val_loss: 2.5099 - val_accuracy: 0.3474
# Epoch 43/50
# 219/219 [==============================] - 8s 36ms/step - loss: 2.4911 - accuracy: 0.3303 - val_loss: 2.4528 - val_accuracy: 0.3821
# Epoch 44/50
# 219/219 [==============================] - 6s 28ms/step - loss: 2.4404 - accuracy: 0.3420 - val_loss: 2.4621 - val_accuracy: 0.3691
# Epoch 45/50
# 219/219 [==============================] - 6s 28ms/step - loss: 2.4422 - accuracy: 0.3374 - val_loss: 2.4349 - val_accuracy: 0.3621
# Epoch 46/50
# 219/219 [==============================] - 6s 29ms/step - loss: 2.4021 - accuracy: 0.3486 - val_loss: 2.3910 - val_accuracy: 0.3658
# Epoch 47/50
# 219/219 [==============================] - 8s 37ms/step - loss: 2.3773 - accuracy: 0.3494 - val_loss: 2.4144 - val_accuracy: 0.3835
# Epoch 48/50
# 219/219 [==============================] - 7s 32ms/step - loss: 2.3595 - accuracy: 0.3557 - val_loss: 2.3722 - val_accuracy: 0.3691
# Epoch 49/50
# 219/219 [==============================] - 6s 28ms/step - loss: 2.3353 - accuracy: 0.3579 - val_loss: 2.3754 - val_accuracy: 0.3761
# Epoch 50/50
# 219/219 [==============================] - 8s 37ms/step - loss: 2.2982 - accuracy: 0.3636 - val_loss: 2.3188 - val_accuracy: 0.3855

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "/content/data_15.json"


def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=100)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[2]
    y_to_predict = y_test[2]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 11, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 64, 6, 32)        0
#  )
#
#  batch_normalization (BatchN  (None, 64, 6, 32)        128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 62, 4, 32)         9248
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 2, 32)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 31, 2, 32)        128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 30, 1, 32)         4128
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 1, 32)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 15, 1, 32)        128
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 480)               0
#
#  dense_4 (Dense)             (None, 64)                30784
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 45,514
# Trainable params: 45,322
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/200
# 188/188 [==============================] - 12s 62ms/step - loss: 2.3566 - accuracy: 0.2381 - val_loss: 1.8218 - val_accuracy: 0.3420
# Epoch 2/200
# 188/188 [==============================] - 13s 70ms/step - loss: 1.8353 - accuracy: 0.3675 - val_loss: 1.5697 - val_accuracy: 0.4300
# Epoch 3/200
# 188/188 [==============================] - 12s 63ms/step - loss: 1.6674 - accuracy: 0.4177 - val_loss: 1.4663 - val_accuracy: 0.4700
# Epoch 4/200
# 188/188 [==============================] - 12s 62ms/step - loss: 1.5377 - accuracy: 0.4474 - val_loss: 1.3812 - val_accuracy: 0.5067
# Epoch 5/200
# 188/188 [==============================] - 12s 62ms/step - loss: 1.4594 - accuracy: 0.4867 - val_loss: 1.3254 - val_accuracy: 0.5233
# Epoch 6/200
# 188/188 [==============================] - 15s 80ms/step - loss: 1.3976 - accuracy: 0.4974 - val_loss: 1.2750 - val_accuracy: 0.5347
# Epoch 7/200
# 188/188 [==============================] - 12s 63ms/step - loss: 1.3345 - accuracy: 0.5203 - val_loss: 1.2333 - val_accuracy: 0.5560
# Epoch 8/200
# 188/188 [==============================] - 12s 62ms/step - loss: 1.2869 - accuracy: 0.5421 - val_loss: 1.1929 - val_accuracy: 0.5747
# Epoch 9/200
# 188/188 [==============================] - 12s 63ms/step - loss: 1.2470 - accuracy: 0.5564 - val_loss: 1.1649 - val_accuracy: 0.5827
# Epoch 10/200
# 188/188 [==============================] - 13s 72ms/step - loss: 1.1969 - accuracy: 0.5788 - val_loss: 1.1559 - val_accuracy: 0.5867
# Epoch 11/200
# 188/188 [==============================] - 12s 63ms/step - loss: 1.1637 - accuracy: 0.5856 - val_loss: 1.1238 - val_accuracy: 0.6007
# Epoch 12/200
# 188/188 [==============================] - 12s 63ms/step - loss: 1.1463 - accuracy: 0.5956 - val_loss: 1.0897 - val_accuracy: 0.6120
# Epoch 13/200
# 188/188 [==============================] - 12s 62ms/step - loss: 1.0953 - accuracy: 0.6125 - val_loss: 1.0713 - val_accuracy: 0.6213
# Epoch 14/200
# 188/188 [==============================] - 13s 71ms/step - loss: 1.0702 - accuracy: 0.6220 - val_loss: 1.0702 - val_accuracy: 0.6153
# Epoch 15/200
# 188/188 [==============================] - 12s 63ms/step - loss: 1.0490 - accuracy: 0.6296 - val_loss: 1.0611 - val_accuracy: 0.6200
# Epoch 16/200
# 188/188 [==============================] - 12s 62ms/step - loss: 1
200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1385 - accuracy: 0.9560 - val_loss: 1.2338 - val_accuracy: 0.7033
# Epoch 151/200
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1451 - accuracy: 0.9496 - val_loss: 1.1907 - val_accuracy: 0.7093
# Epoch 152/200
# 188/188 [==============================] - 14s 75ms/step - loss: 0.1385 - accuracy: 0.9528 - val_loss: 1.0971 - val_accuracy: 0.7320
# Epoch 153/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1434 - accuracy: 0.9511 - val_loss: 1.1001 - val_accuracy: 0.7307
# Epoch 154/200
# 188/188 [==============================] - 13s 69ms/step - loss: 0.1421 - accuracy: 0.9535 - val_loss: 1.1103 - val_accuracy: 0.7220
# Epoch 155/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1370 - accuracy: 0.9545 - val_loss: 1.0404 - val_accuracy: 0.7353
# Epoch 156/200
# 188/188 [==============================] - 16s 84ms/step - loss: 0.1207 - accuracy: 0.9600 - val_loss: 1.0553 - val_accuracy: 0.7293
# Epoch 157/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1288 - accuracy: 0.9581 - val_loss: 1.0868 - val_accuracy: 0.7287
# Epoch 158/200
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1362 - accuracy: 0.9535 - val_loss: 1.1021 - val_accuracy: 0.7287
# Epoch 159/200
# 188/188 [==============================] - 14s 75ms/step - loss: 0.1312 - accuracy: 0.9570 - val_loss: 1.1925 - val_accuracy: 0.7227
# Epoch 160/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1246 - accuracy: 0.9606 - val_loss: 1.1316 - val_accuracy: 0.7240
# Epoch 161/200
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1330 - accuracy: 0.9533 - val_loss: 1.1262 - val_accuracy: 0.7320
# Epoch 162/200
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1308 - accuracy: 0.9556 - val_loss: 1.0919 - val_accuracy: 0.7280
# Epoch 163/200
# 188/188 [==============================] - 14s 77ms/step - loss: 0.1169 - accuracy: 0.9651 - val_loss: 1.1348 - val_accuracy: 0.7280
# Epoch 164/200
# 188/188 [==============================] - 13s 69ms/step - loss: 0.1200 - accuracy: 0.9588 - val_loss: 1.1369 - val_accuracy: 0.7320
# Epoch 165/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1235 - accuracy: 0.9581 - val_loss: 1.1550 - val_accuracy: 0.7260
# Epoch 166/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1240 - accuracy: 0.9595 - val_loss: 1.1300 - val_accuracy: 0.7333
# Epoch 167/200
# 188/188 [==============================] - 14s 76ms/step - loss: 0.1207 - accuracy: 0.9595 - val_loss: 1.1438 - val_accuracy: 0.7247
# Epoch 168/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1191 - accuracy: 0.9605 - val_loss: 1.0967 - val_accuracy: 0.7380
# Epoch 169/200
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1187 - accuracy: 0.9638 - val_loss: 1.1565 - val_accuracy: 0.7313
# Epoch 170/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1134 - accuracy: 0.9643 - val_loss: 1.1418 - val_accuracy: 0.7347
# Epoch 171/200
# 188/188 [==============================] - 14s 77ms/step - loss: 0.1142 - accuracy: 0.9598 - val_loss: 1.1827 - val_accuracy: 0.7227
# Epoch 172/200
# 188/188 [==============================] - 14s 76ms/step - loss: 0.1077 - accuracy: 0.9641 - val_loss: 1.1314 - val_accuracy: 0.7373
# Epoch 173/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1260 - accuracy: 0.9581 - val_loss: 1.1427 - val_accuracy: 0.7333
# Epoch 174/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1084 - accuracy: 0.9635 - val_loss: 1.1787 - val_accuracy: 0.7300
# Epoch 175/200
# 188/188 [==============================] - 14s 76ms/step - loss: 0.1134 - accuracy: 0.9623 - val_loss: 1.1659 - val_accuracy: 0.7307
# Epoch 176/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1062 - accuracy: 0.9640 - val_loss: 1.1937 - val_accuracy: 0.7347
# Epoch 177/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1100 - accuracy: 0.9641 - val_loss: 1.1620 - val_accuracy: 0.7213
# Epoch 178/200
# 188/188 [==============================] - 14s 72ms/step - loss: 0.1091 - accuracy: 0.9663 - val_loss: 1.1420 - val_accuracy: 0.7333
# Epoch 179/200
# 188/188 [==============================] - 14s 74ms/step - loss: 0.1128 - accuracy: 0.9598 - val_loss: 1.2026 - val_accuracy: 0.7193
# Epoch 180/200
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1040 - accuracy: 0.9658 - val_loss: 1.2469 - val_accuracy: 0.7300
# Epoch 181/200
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1190 - accuracy: 0.9605 - val_loss: 1.1469 - val_accuracy: 0.7307
# Epoch 182/200
# 188/188 [==============================] - 14s 76ms/step - loss: 0.1078 - accuracy: 0.9650 - val_loss: 1.1394 - val_accuracy: 0.7360
# Epoch 183/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1044 - accuracy: 0.9668 - val_loss: 1.1982 - val_accuracy: 0.7247
# Epoch 184/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1066 - accuracy: 0.9670 - val_loss: 1.1632 - val_accuracy: 0.7353
# Epoch 185/200
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1100 - accuracy: 0.9641 - val_loss: 1.2340 - val_accuracy: 0.7093
# Epoch 186/200
# 188/188 [==============================] - 14s 75ms/step - loss: 0.1034 - accuracy: 0.9656 - val_loss: 1.1811 - val_accuracy: 0.7360
# Epoch 187/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1038 - accuracy: 0.9628 - val_loss: 1.2444 - val_accuracy: 0.7173
# Epoch 188/200
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1051 - accuracy: 0.9640 - val_loss: 1.1519 - val_accuracy: 0.7307
# Epoch 189/200
# 188/188 [==============================] - 14s 75ms/step - loss: 0.1207 - accuracy: 0.9568 - val_loss: 1.2774 - val_accuracy: 0.7147
# Epoch 190/200
# 188/188 [==============================] - 14s 76ms/step - loss: 0.0954 - accuracy: 0.9703 - val_loss: 1.2386 - val_accuracy: 0.7273
# Epoch 191/200
# 188/188 [==============================] - 13s 69ms/step - loss: 0.1041 - accuracy: 0.9675 - val_loss: 1.2401 - val_accuracy: 0.7267
# Epoch 192/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1027 - accuracy: 0.9682 - val_loss: 1.2289 - val_accuracy: 0.7253
# Epoch 193/200
# 188/188 [==============================] - 13s 68ms/step - loss: 0.0965 - accuracy: 0.9680 - val_loss: 1.2380 - val_accuracy: 0.7267
# Epoch 194/200
# 188/188 [==============================] - 15s 78ms/step - loss: 0.0991 - accuracy: 0.9665 - val_loss: 1.1838 - val_accuracy: 0.7327
# Epoch 195/200
# 188/188 [==============================] - 13s 69ms/step - loss: 0.0972 - accuracy: 0.9668 - val_loss: 1.1853 - val_accuracy: 0.7293
# Epoch 196/200
# 188/188 [==============================] - 13s 69ms/step - loss: 0.0930 - accuracy: 0.9703 - val_loss: 1.2621 - val_accuracy: 0.7320
# Epoch 197/200
# 188/188 [==============================] - 13s 69ms/step - loss: 0.1014 - accuracy: 0.9672 - val_loss: 1.3383 - val_accuracy: 0.7067
# Epoch 198/200
# 188/188 [==============================] - 14s 76ms/step - loss: 0.1051 - accuracy: 0.9595 - val_loss: 1.2103 - val_accuracy: 0.7227
# Epoch 199/200
# 188/188 [==============================] - 13s 69ms/step - loss: 0.1085 - accuracy: 0.9626 - val_loss: 1.2113 - val_accuracy: 0.7287
# Epoch 200/200
# 188/188 [==============================] - 13s 70ms/step - loss: 0.0949 - accuracy: 0.9687 - val_loss: 1.1930 - val_accuracy: 0.7240
# 79/79 - 1s - loss: 1.1163 - accuracy: 0.7259 - 1s/epoch - 13ms/step
#
# Test accuracy: 0.7258903384208679
# 1/1 [==============================] - 0s 133ms/step
# Target: 2, Predicted label: [2]
